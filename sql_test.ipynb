# %%
import pymysql
import pandas as pd

# %%
# 데이터베이스 연결하기
conn = pymysql.connect(host='127.0.0.1', user='apic', password='1234', db='KBODATA', charset='utf8', cursorclass=pymysql.cursors.DictCursor)
# 통로 만들기
cur = conn.cursor()

# %%
cur.execute('select * from KBO_TABLE;')
result = cur.fetchall()

# %%
pd.DataFrame(result)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cur.execute('DELETE FROM KBO_TABLE WHERE XBH >= 0;')
conn.commit()

# %%
conn.close()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 conn.close()
#
# File ~/miniconda3/envs/kbo_crawl_venv/lib/python3.11/site-packages/pymysql/connections.py:414, in Connection.close(self)
#     405 """
#     406 Send the quit message and close the socket.
#     407
#    (...)    411 :raise Error: If the connection is already closed.
#     412 """
#     413 if self._closed:
# --> 414     raise err.Error("Already closed")
#     415 self._closed = True
#     416 if self._sock is None:
#
# Error: Already closed
